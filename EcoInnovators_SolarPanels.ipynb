# %%
# %pip install\
requests mercantile numpy==1.26.4 pandas pillow shapely opencv-python matplotlib torch torchvision torchaudio ultralytics mlflow
# Out:
# Requirement already satisfied: requests in c:\users\premithius\solar_jupyter\lib\site-packages (2.32.5)
# Requirement already satisfied: mercantile in c:\users\premithius\solar_jupyter\lib\site-packages (1.2.1)
# Requirement already satisfied: numpy==1.26.4 in c:\users\premithius\solar_jupyter\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\premithius\solar_jupyter\lib\site-packages (2.3.3)
# Requirement already satisfied: pillow in c:\users\premithius\solar_jupyter\lib\site-packages (12.0.0)
# Requirement already satisfied: shapely in c:\users\premithius\solar_jupyter\lib\site-packages (2.1.2)
# Requirement already satisfied: opencv-python in c:\users\premithius\solar_jupyter\lib\site-packages (4.11.0.86)
# Requirement already satisfied: matplotlib in c:\users\premithius\solar_jupyter\lib\site-packages (3.10.7)
# Requirement already satisfied: torch in c:\users\premithius\solar_jupyter\lib\site-packages (1.13.1+cpu)
# Requirement already satisfied: torchvision in c:\users\premithius\solar_jupyter\lib\site-packages (0.14.1)
# Requirement already satisfied: torchaudio in c:\users\premithius\solar_jupyter\lib\site-packages (0.13.1+cpu)
# Requirement already satisfied: ultralytics in c:\users\premithius\solar_jupyter\lib\site-packages (8.3.233)
# Collecting mlflow
#   Downloading mlflow-3.6.0-py3-none-any.whl (8.9 MB)
#      ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#       --------------------------------------- 0.1/8.9 MB 3.3 MB/s eta 0:00:03
#      -- ------------------------------------- 0.5/8.9 MB 6.8 MB/s eta 0:00:02
#      ------ --------------------------------- 1.4/8.9 MB 11.0 MB/s eta 0:00:01
#      --------- ------------------------------ 2.1/8.9 MB 12.3 MB/s eta 0:00:01
#      ------------ --------------------------- 2.8/8.9 MB 13.0 MB/s eta 0:00:01
#      ---------------- ----------------------- 3.6/8.9 MB 13.4 MB/s eta 0:00:01
#      -------------------- ------------------- 4.5/8.9 MB 14.5 MB/s eta 0:00:01
#      ----------------------- ---------------- 5.3/8.9 MB 14.7 MB/s eta 0:00:01
#      --------------------------- ------------ 6.2/8.9 MB 15.1 MB/s eta 0:00:01
#      ------------------------------ --------- 6.8/8.9 MB 14.5 MB/s eta 0:00:01
#      ---------------------------------- ----- 7.6/8.9 MB 15.1 MB/s eta 0:00:01
#      ------------------------------------- -- 8.4/8.9 MB 15.3 MB/s eta 0:00:01
#      ---------------------------------------  8.9/8.9 MB 14.9 MB/s eta 0:00:01
#      ---------------------------------------- 8.9/8.9 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\premithius\solar_jupyter\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\premithius\solar_jupyter\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\premithius\solar_jupyter\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: click>=3.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from mercantile) (8.3.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\premithius\solar_jupyter\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\premithius\solar_jupyter\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pyparsing>=3 in c:\users\premithius\solar_jupyter\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\premithius\solar_jupyter\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: typing-extensions in c:\users\premithius\solar_jupyter\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from ultralytics) (7.1.3)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\premithius\solar_jupyter\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: polars>=0.20.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from ultralytics) (1.35.2)
# Collecting docker<8,>=4.0.0
#   Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#      ---------------------------------------- 0.0/147.8 kB ? eta -:--:--
#      ---------------------------------------- 147.8/147.8 kB ? eta 0:00:00
# Collecting Flask<4
#   Downloading flask-3.1.2-py3-none-any.whl (103 kB)
#      ---------------------------------------- 0.0/103.3 kB ? eta -:--:--
#      ---------------------------------------- 103.3/103.3 kB ? eta 0:00:00
# Collecting alembic!=1.10.0,<2
#   Downloading alembic-1.17.2-py3-none-any.whl (248 kB)
#      ---------------------------------------- 0.0/248.6 kB ? eta -:--:--
#      ---------------------------------------- 248.6/248.6 kB ? eta 0:00:00
# Collecting scikit-learn<2
#   Using cached scikit_learn-1.7.2-cp310-cp310-win_amd64.whl (8.9 MB)
# Collecting huey<3,>=2.5.0
#   Downloading huey-2.5.4-py3-none-any.whl (76 kB)
#      ---------------------------------------- 0.0/76.8 kB ? eta -:--:--
#      ---------------------------------------- 76.8/76.8 kB ? eta 0:00:00
# Collecting mlflow-tracing==3.6.0
#   Downloading mlflow_tracing-3.6.0-py3-none-any.whl (1.3 MB)
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ------------------------ --------------- 0.8/1.3 MB 16.3 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 20.2 MB/s eta 0:00:00
# Collecting waitress<4
#   Downloading waitress-3.0.2-py3-none-any.whl (56 kB)
#      ---------------------------------------- 0.0/56.2 kB ? eta -:--:--
#      ---------------------------------------- 56.2/56.2 kB ? eta 0:00:00
# Collecting pyarrow<23,>=4.0.0
#   Downloading pyarrow-22.0.0-cp310-cp310-win_amd64.whl (28.1 MB)
#      ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#      - -------------------------------------- 0.7/28.1 MB 15.0 MB/s eta 0:00:02
#      -- ------------------------------------- 1.5/28.1 MB 19.2 MB/s eta 0:00:02
#      --- ------------------------------------ 2.2/28.1 MB 17.5 MB/s eta 0:00:02
#      ---- ----------------------------------- 3.1/28.1 MB 16.4 MB/s eta 0:00:02
#      ----- ---------------------------------- 4.0/28.1 MB 15.8 MB/s eta 0:00:02
#      ------ --------------------------------- 4.7/28.1 MB 16.7 MB/s eta 0:00:02
#      ------- -------------------------------- 5.3/28.1 MB 16.0 MB/s eta 0:00:02
#      -------- ------------------------------- 5.9/28.1 MB 15.0 MB/s eta 0:00:02
#      --------- ------------------------------ 6.7/28.1 MB 15.3 MB/s eta 0:00:02
#      ---------- ----------------------------- 7.6/28.1 MB 15.7 MB/s eta 0:00:02
#      ------------ --------------------------- 8.5/28.1 MB 16.0 MB/s eta 0:00:02
#      ------------- -------------------------- 9.4/28.1 MB 16.2 MB/s eta 0:00:02
#      -------------- ------------------------ 10.4/28.1 MB 16.4 MB/s eta 0:00:02
#      --------------- ----------------------- 11.2/28.1 MB 17.2 MB/s eta 0:00:01
#      ---------------- ---------------------- 12.0/28.1 MB 16.8 MB/s eta 0:00:01
#      ----------------- --------------------- 12.8/28.1 MB 16.8 MB/s eta 0:00:01
#      ------------------ -------------------- 13.7/28.1 MB 17.7 MB/s eta 0:00:01
#      -------------------- ------------------ 14.5/28.1 MB 17.2 MB/s eta 0:00:01
#      --------------------- ----------------- 15.5/28.1 MB 17.7 MB/s eta 0:00:01
#      ---------------------- ---------------- 16.3/28.1 MB 18.2 MB/s eta 0:00:01
#      ----------------------- --------------- 17.0/28.1 MB 18.2 MB/s eta 0:00:01
#      ------------------------ -------------- 17.9/28.1 MB 18.2 MB/s eta 0:00:01
#      ------------------------- ------------- 18.1/28.1 MB 17.7 MB/s eta 0:00:01
#      ------------------------- ------------- 18.2/28.1 MB 16.4 MB/s eta 0:00:01
#      ------------------------- ------------- 18.3/28.1 MB 14.9 MB/s eta 0:00:01
#      ------------------------- ------------- 18.4/28.1 MB 13.9 MB/s eta 0:00:01
#      -------------------------- ------------ 18.7/28.1 MB 13.6 MB/s eta 0:00:01
#      --------------------------- ----------- 19.5/28.1 MB 13.6 MB/s eta 0:00:01
#      ---------------------------- ---------- 20.2/28.1 MB 13.4 MB/s eta 0:00:01
#      ----------------------------- --------- 21.2/28.1 MB 13.4 MB/s eta 0:00:01
#      ------------------------------ -------- 22.1/28.1 MB 13.4 MB/s eta 0:00:01
#      -------------------------------- ------ 23.1/28.1 MB 13.6 MB/s eta 0:00:01
#      --------------------------------- ----- 23.8/28.1 MB 13.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 24.6/28.1 MB 13.1 MB/s eta 0:00:01
#      ----------------------------------- --- 25.5/28.1 MB 13.4 MB/s eta 0:00:01
#      ------------------------------------ -- 26.3/28.1 MB 13.1 MB/s eta 0:00:01
#      ------------------------------------- - 27.0/28.1 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------  28.1/28.1 MB 13.4 MB/s eta 0:00:01
#      --------------------------------------- 28.1/28.1 MB 12.3 MB/s eta 0:00:00
# Collecting sqlalchemy<3,>=1.4.0
#   Downloading sqlalchemy-2.0.44-cp310-cp310-win_amd64.whl (2.1 MB)
#      ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#      ------------- -------------------------- 0.7/2.1 MB 22.8 MB/s eta 0:00:01
#      ------------------------ --------------- 1.3/2.1 MB 16.4 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 16.9 MB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 15.1 MB/s eta 0:00:00
# Collecting Flask-CORS<7
#   Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Collecting graphene<4
#   Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#      ---------------------------------------- 0.0/114.9 kB ? eta -:--:--
#      ---------------------------------------- 114.9/114.9 kB ? eta 0:00:00
# Collecting mlflow-skinny==3.6.0
#   Downloading mlflow_skinny-3.6.0-py3-none-any.whl (2.4 MB)
#      ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#      --------- ------------------------------ 0.6/2.4 MB 17.9 MB/s eta 0:00:01
#      ----------------------- ---------------- 1.4/2.4 MB 14.5 MB/s eta 0:00:01
#      --------------------------------- ------ 2.0/2.4 MB 17.8 MB/s eta 0:00:01
#      ---------------------------------------- 2.4/2.4 MB 15.0 MB/s eta 0:00:00
# Collecting cryptography<47,>=43.0.0
#   Downloading cryptography-46.0.3-cp38-abi3-win_amd64.whl (3.5 MB)
#      ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#      ------ --------------------------------- 0.5/3.5 MB 16.3 MB/s eta 0:00:01
#      -------------- ------------------------- 1.3/3.5 MB 16.0 MB/s eta 0:00:01
#      ---------------------- ----------------- 2.0/3.5 MB 15.6 MB/s eta 0:00:01
#      ------------------------------ --------- 2.7/3.5 MB 15.5 MB/s eta 0:00:01
#      ---------------------------------------  3.5/3.5 MB 15.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.5/3.5 MB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: protobuf<7,>=3.12.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from mlflow-skinny==3.6.0->mlflow) (6.33.1)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from mlflow-skinny==3.6.0->mlflow) (2.12.5)
# Collecting fastapi<1
#   Downloading fastapi-0.123.4-py3-none-any.whl (111 kB)
#      ---------------------------------------- 0.0/111.3 kB ? eta -:--:--
#      ---------------------------------------- 111.3/111.3 kB ? eta 0:00:00
# Collecting uvicorn<1
#   Downloading uvicorn-0.38.0-py3-none-any.whl (68 kB)
#      ---------------------------------------- 0.0/68.1 kB ? eta -:--:--
#      ---------------------------------------- 68.1/68.1 kB ? eta 0:00:00
# Collecting opentelemetry-proto<3,>=1.9.0
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
#      ---------------------------------------- 0.0/72.5 kB ? eta -:--:--
#      ---------------------------------------- 72.5/72.5 kB ? eta 0:00:00
# Collecting sqlparse<1,>=0.4.0
#   Downloading sqlparse-0.5.4-py3-none-any.whl (45 kB)
#      ---------------------------------------- 0.0/45.9 kB ? eta -:--:--
#      ---------------------------------------- 45.9/45.9 kB ? eta 0:00:00
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\premithius\solar_jupyter\lib\site-packages (from mlflow-skinny==3.6.0->mlflow) (3.1.45)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Collecting cloudpickle<4
#   Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#      ---------------------------------------- 0.0/132.3 kB ? eta -:--:--
#      ---------------------------------------- 132.3/132.3 kB ? eta 0:00:00
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from mlflow-skinny==3.6.0->mlflow) (1.2.1)
# Collecting databricks-sdk<1,>=0.20.0
#   Downloading databricks_sdk-0.73.0-py3-none-any.whl (753 kB)
#      ---------------------------------------- 0.0/753.9 kB ? eta -:--:--
#      ---------------------------- -------- 573.4/753.9 kB 18.2 MB/s eta 0:00:01
#      ------------------------------------- 753.9/753.9 kB 11.8 MB/s eta 0:00:00
# Collecting opentelemetry-api<3,>=1.9.0
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#      ---------------------------------------- 0.0/65.9 kB ? eta -:--:--
#      ---------------------------------------- 65.9/65.9 kB ? eta 0:00:00
# Collecting cachetools<7,>=5.0.0
#   Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Requirement already satisfied: tomli in c:\users\premithius\solar_jupyter\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (2.3.0)
# Collecting Mako
#   Downloading mako-1.3.10-py3-none-any.whl (78 kB)
#      ---------------------------------------- 0.0/78.5 kB ? eta -:--:--
#      ---------------------------------------- 78.5/78.5 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\premithius\solar_jupyter\lib\site-packages (from click>=3.0->mercantile) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from cryptography<47,>=43.0.0->mlflow) (2.0.0)
# Collecting pywin32>=304
#   Downloading pywin32-311-cp310-cp310-win_amd64.whl (9.6 MB)
#      ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/9.6 MB 15.4 MB/s eta 0:00:01
#      ----- ---------------------------------- 1.2/9.6 MB 15.6 MB/s eta 0:00:01
#      -------- ------------------------------- 1.9/9.6 MB 13.7 MB/s eta 0:00:01
#      ---------- ----------------------------- 2.6/9.6 MB 13.7 MB/s eta 0:00:01
#      -------------- ------------------------- 3.5/9.6 MB 14.8 MB/s eta 0:00:01
#      ----------------- ---------------------- 4.2/9.6 MB 14.8 MB/s eta 0:00:01
#      -------------------- ------------------- 5.0/9.6 MB 15.1 MB/s eta 0:00:01
#      ----------------------- ---------------- 5.6/9.6 MB 14.9 MB/s eta 0:00:01
#      ------------------------- -------------- 6.2/9.6 MB 15.2 MB/s eta 0:00:01
#      ---------------------------- ----------- 6.8/9.6 MB 15.0 MB/s eta 0:00:01
#      -------------------------------- ------- 7.8/9.6 MB 15.1 MB/s eta 0:00:01
#      ----------------------------------- ---- 8.4/9.6 MB 15.0 MB/s eta 0:00:01
#      -------------------------------------- - 9.3/9.6 MB 15.2 MB/s eta 0:00:01
#      ---------------------------------------- 9.6/9.6 MB 14.6 MB/s eta 0:00:00
# Collecting itsdangerous>=2.2.0
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\premithius\solar_jupyter\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Collecting blinker>=1.9.0
#   Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from Flask<4->mlflow) (3.1.4)
# Collecting graphql-core<3.3,>=3.1
#   Downloading graphql_core-3.2.7-py3-none-any.whl (207 kB)
#      ---------------------------------------- 0.0/207.3 kB ? eta -:--:--
#      ------------------------------------- 207.3/207.3 kB 12.3 MB/s eta 0:00:00
# Collecting graphql-relay<3.3,>=3.1
#   Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\premithius\solar_jupyter\lib\site-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: six>=1.5 in c:\users\premithius\solar_jupyter\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting greenlet>=1
#   Downloading greenlet-3.2.4-cp310-cp310-win_amd64.whl (298 kB)
#      ---------------------------------------- 0.0/298.7 kB ? eta -:--:--
#      ------------------------------------- 298.7/298.7 kB 18.0 MB/s eta 0:00:00
# Requirement already satisfied: pycparser in c:\users\premithius\solar_jupyter\lib\site-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow) (2.23)
# Collecting google-auth~=2.0
#   Downloading google_auth-2.43.0-py2.py3-none-any.whl (223 kB)
#      ---------------------------------------- 0.0/223.1 kB ? eta -:--:--
#      ---------------------------------------- 223.1/223.1 kB ? eta 0:00:00
# Collecting starlette<0.51.0,>=0.40.0
#   Downloading starlette-0.50.0-py3-none-any.whl (74 kB)
#      ---------------------------------------- 0.0/74.0 kB ? eta -:--:--
#      ---------------------------------------- 74.0/74.0 kB ? eta 0:00:00
# Collecting annotated-doc>=0.0.2
#   Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (4.0.12)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Collecting opentelemetry-semantic-conventions==0.59b0
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#      ---------------------------------------- 0.0/208.0 kB ? eta -:--:--
#      ------------------------------------- 208.0/208.0 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\premithius\solar_jupyter\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\premithius\solar_jupyter\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.4.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\premithius\solar_jupyter\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.6.0->mlflow) (0.7.0)
# Requirement already satisfied: h11>=0.8 in c:\users\premithius\solar_jupyter\lib\site-packages (from uvicorn<1->mlflow-skinny==3.6.0->mlflow) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.6.0->mlflow) (5.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\premithius\solar_jupyter\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (4.7.2)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\premithius\solar_jupyter\lib\site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (4.12.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\premithius\solar_jupyter\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.6.0->mlflow) (1.3.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\premithius\solar_jupyter\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.6.0->mlflow) (0.6.1)
# Installing collected packages: pywin32, huey, zipp, waitress, threadpoolctl, sqlparse, pyasn1-modules, pyarrow, opentelemetry-proto, Mako, joblib, itsdangerous, greenlet, graphql-core, cloudpickle, cachetools, blinker, annotated-doc, uvicorn, sqlalchemy, scikit-learn, importlib_metadata, graphql-relay, google-auth, Flask, docker, cryptography, starlette, opentelemetry-api, graphene, Flask-CORS, databricks-sdk, alembic, opentelemetry-semantic-conventions, fastapi, opentelemetry-sdk, mlflow-tracing, mlflow-skinny, mlflow
# Successfully installed Flask-3.1.2 Flask-CORS-6.0.1 Mako-1.3.10 alembic-1.17.2 annotated-doc-0.0.4 blinker-1.9.0 cachetools-6.2.2 cloudpickle-3.1.2 cryptography-46.0.3 databricks-sdk-0.73.0 docker-7.1.0 fastapi-0.123.4 google-auth-2.43.0 graphene-3.4.3 graphql-core-3.2.7 graphql-relay-3.2.0 greenlet-3.2.4 huey-2.5.4 importlib_metadata-8.7.0 itsdangerous-2.2.0 joblib-1.5.2 mlflow-3.6.0 mlflow-skinny-3.6.0 mlflow-tracing-3.6.0 opentelemetry-api-1.38.0 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 pyarrow-22.0.0 pyasn1-modules-0.4.2 pywin32-311 scikit-learn-1.7.2 sqlalchemy-2.0.44 sqlparse-0.5.4 starlette-0.50.0 threadpoolctl-3.6.0 uvicorn-0.38.0 waitress-3.0.2 zipp-3.23.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\premithius\solar_jupyter\lib\site-packages)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.3
# [notice] To update, run: C:\Users\Premithius\solar_jupyter\Scripts\python.exe -m pip install --upgrade pip

# %%
import os
import math
import json
import requests
from io import BytesIO
from pathlib import Path
import mercantile
import numpy as np
import pandas as pd
from PIL import Image
from shapely.geometry import Polygon
import cv2
import matplotlib.pyplot as plt

import torch
from ultralytics import YOLO

PIXEL_TO_SQM = 0.04
BUFFER_RADIUS_SQFT = 1200

# %%
def sqft_area_to_radius_m(area_sqft):
    """Convert circular area (sqft) → radius in meters"""
    area_m2 = area_sqft * SQFT_TO_SQM
    return math.sqrt(area_m2 / math.pi)


def meters_to_lat_lon(dx, dy, lat):
    dlat = dy / 111320.0
    dlon = dx / (111320.0 * math.cos(math.radians(lat)))
    return dlat, dlon

# %%
ESRI_TILE_URL = (
    "https://services.arcgisonline.com/ArcGIS/rest/services/"
    "World_Imagery/MapServer/tile/{z}/{y}/{x}"
)
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

def fetch_imagery(lat, lon, out_path, zoom=19, grid_size=3):
    center_tile = mercantile.tile(lon, lat, zoom)
    half = grid_size // 2
    tile_images = {}
    tile_size = None

    for dx in range(-half, half + 1):
        for dy in range(-half, half + 1):
            x = center_tile.x + dx
            y = center_tile.y + dy
            url = ESRI_TILE_URL.format(z=zoom, x=x, y=y)
            r = requests.get(url, headers=HEADERS, timeout=10)
            if r.status_code != 200:
                return None
            img = Image.open(BytesIO(r.content)).convert("RGB")
            tile_images[(dx, dy)] = img
            tile_size = img.size[0]

    stitched = Image.new("RGB", (tile_size * grid_size, tile_size * grid_size))
    for dx in range(-half, half + 1):
        for dy in range(-half, half + 1):
            img = tile_images[(dx, dy)]
            col = dx + half
            row = dy + half
            stitched.paste(img, (col * tile_size, row * tile_size))

    stitched = stitched.resize((640, 640))
    stitched.save(out_path)
    return out_path
class SolarSegmentationModel:
    def __init__(self, model_path=None, device='cpu'):
        if model_path:
            self.model = YOLO(model_path)
        else:
            self.model = None
        self.device = device

    def predict_mask(self, image: Image.Image):
        if self.model is None:
            # fallback dummy mask
            arr = np.array(image.resize((256, 256))).mean(axis=2)
            return (arr < 128).astype(np.uint8)
        results = self.model.predict(np.array(image), conf=0.3, device=self.device)
        mask = np.zeros((image.height, image.width), dtype=np.uint8)
        for r in results:
            if hasattr(r, "masks") and r.masks is not None:
                mask_r = r.masks.data[0].cpu().numpy()  # shape: HxW
                mask = np.maximum(mask, mask_r.astype(np.uint8))
        return mask

# %%
class SolarSegmentationModel:
    def __init__(self, model_path: str):
        self.model = YOLO(model_path)

    def predict_mask(self, image_path: str):
        results = self.model(image_path, conf=0.25, iou=0.5)
        r = results[0]
        if r.masks is None:
            return None
        masks = r.masks.data.cpu().numpy()
        combined = masks.sum(axis=0)
        return (combined > 0).astype(np.uint8)

# %%
def mask_area_m2(mask, meters_per_pixel=0.3):
    if mask is None:
        return 0.0
    pixel_area = meters_per_pixel ** 2
    return float(mask.sum() * pixel_area)

# %%
def qc_status(image, mask):
    if image is None or mask is None:
        return "NOT_VERIFIABLE"
    if mask.sum() < 20:
        return "VERIFIABLE"
    return "VERIFIABLE"

# %%
def process_sample(row, model, output_dir):
    sid = str(row['sample_id'])
    lat, lon = row['latitude'], row['longitude']

    out_dir = output_dir / sid
    out_dir.mkdir(parents=True, exist_ok=True)

    img_path = out_dir / "image.png"
    fetch_imagery(lat, lon, img_path)

    image = Image.open(img_path)
    mask = model.predict_mask(str(img_path))

    area_1200 = mask_area_m2(mask)

    if area_1200 > 1.0:
        presence = True
        buffer_used = 1200
        area_m2 = area_1200
    else:
        presence = area_1200 > 0
        buffer_used = 2400
        area_m2 = area_1200

    qc = qc_status(image, mask)

    if mask is not None:
        Image.fromarray(mask * 255).save(out_dir / "mask.png")

    result = {
        "sample_id": sid,
        "latitude": lat,
        "longitude": lon,
        "pv_present": presence,
        "buffer_sqft": buffer_used,
        "pv_area_m2": round(area_m2, 2),
        "qc_status": qc
    }

    with open(out_dir / "result.json", "w") as f:
        json.dump(result, f, indent=2)

    return result

# %%
def run_yolo_excel_pipeline(
    excel_path,
    model_path,
    output_dir,
    imgsz=640,
    conf=0.3
):
    """
    Excel: sample_id | latitude | longitude
    Uses existing ESRI fetch_imagery() function
    """
    df = pd.read_excel(excel_path)
    model = YOLO(model_path)

    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)
    yolo_out_dir = output_dir / "yolo_results"
    yolo_out_dir.mkdir(parents=True, exist_ok=True)

    summary = []

    for _, row in df.iterrows():
        sid = str(row["sample_id"])
        lat = float(row["latitude"])
        lon = float(row["longitude"])

        print(f"Processing {sid}")

        sample_dir = output_dir / sid
        sample_dir.mkdir(parents=True, exist_ok=True)
        result_json_path = sample_dir / "result.json"
        
        base_payload = {
            "sample_id": int(sid) if sid.isdigit() else sid,
            "lat": lat,
            "lon": lon,
            "has_solar": False,
            "confidence": 0.0,
            "pv_area_sqm_est": 0.0,
            "buffer_radius_sqft": BUFFER_RADIUS_SQFT,
            "qc_status": "PENDING",
            "bbox_or_mask": None,
            "image_metadata": {
                "source": "ESRI",
                "capture_date": "UNKNOWN"
            }
        }
        
        with open(result_json_path, "w") as f:
            json.dump(base_payload, f, indent=2)
        image_path = sample_dir / "image.png"
        fetch_imagery(lat, lon, image_path)

        img = Image.open(image_path).convert("RGB")
        img_np = np.array(img)
        mean_val = img_np.mean()
        std_val = img_np.std()
        
        print(f"Image stats — mean: {mean_val:.2f}, std: {std_val:.2f}")
        
        if std_val < 7:
            base_payload.update({
                "qc_status": "NOT_VERIFIABLE",
                "reason": "Imagery unavailable or low detail"
            })
        
            with open(result_json_path, "w") as f:
                json.dump(base_payload, f, indent=2)
        
            summary.append({
                "sample_id": sid,
                "latitude": lat,
                "longitude": lon,
                "pv_present": False,
                "num_panels": 0,
                "total_area_pixels": 0,
                "qc_status": "NOT_VERIFIABLE"
            })
            print("Imagery invalid skipping yolo")
            continue

        results = model.predict(
            source=image_path,
            imgsz=imgsz,
            conf=conf,
            save=True,
            project=sample_dir,
            name="yolo",
            exist_ok=True
        )
        result = results[0]
        detections = []
        total_area_px = 0

        if result.masks is not None:
            for i, mask in enumerate(result.masks.data):
                mask_np = (mask.cpu().numpy() > 0.5).astype(np.uint8)

                contours, _ = cv2.findContours(
                    mask_np,
                    cv2.RETR_EXTERNAL,
                    cv2.CHAIN_APPROX_SIMPLE
                )

                for cnt in contours:
                    if cv2.contourArea(cnt) < 100:
                        continue

                    poly = Polygon(cnt.squeeze())
                    area_px = int(poly.area)

                    detections.append({
                        "class": "solar_panel",
                        "confidence": round(float(result.boxes.conf[i]), 3),
                        "area_pixels": area_px,
                        "polygon": cnt.squeeze().tolist()
                    })

                    total_area_px += area_px
        mask_img = np.zeros(
            (img.height, img.width),
            dtype=np.uint8
        )

        for d in detections:
            pts = np.array(d["polygon"], dtype=np.int32)
            cv2.fillPoly(mask_img, [pts], 255)

        Image.fromarray(mask_img).save(sample_dir / "mask.png")
        has_solar = len(detections) > 0
        
        if has_solar:
            max_conf = max(d["confidence"] for d in detections)
            area_sqm = round(total_area_px * PIXEL_TO_SQM, 2)
        
            base_payload.update({
                "has_solar": True,
                "confidence": round(max_conf, 3),
                "pv_area_sqm_est": area_sqm,
                "qc_status": "VERIFIABLE",
                "bbox_or_mask": detections[0]["polygon"]
            })
        else:
            base_payload.update({
                "has_solar": False,
                "confidence": 0.0,
                "pv_area_sqm_est": 0.0,
                "qc_status": "VERIFIABLE",
                "bbox_or_mask": None
            })
        with open(result_json_path, "w") as f:
            json.dump(base_payload, f, indent=2)
    summary_df = pd.DataFrame(summary)
    summary_df.to_excel(output_dir / "summary.xlsx", index=False)
    print("All samples processed using ESRI imagery")
    return summary_df

# %%
summary_df = run_yolo_excel_pipeline(
    excel_path="samples.xlsx",
    model_path="yolov8s-seg-solar-panels/best.pt",
    output_dir="outputs"
)
summary_df.head()

# %%
import mlflow
import mlflow.pytorch
mlflow.start_run(run_name="solar_panel_training")
for epoch in range(num_epochs):
    mlflow.log_metric("loss", loss, step=epoch)
    mlflow.log_metric("f1_score", f1, step=epoch)
    mlflow.log_metric("rmse", rmse, step=epoch)
mlflow.pytorch.log_model(model, "model")
mlflow.end_run()
